# %%
# Combining the above two code cells to perform the Analysis and saving the data in the output file

import os
import nltk
from nltk.corpus import cmudict
import pyphen
import string
from nltk.tokenize import word_tokenize
import pandas as pd
filess=['txtfiles\\37.0.txt', 'txtfiles\\38.0.txt', 'txtfiles\\39.0.txt', 'txtfiles\\40.0.txt', 'txtfiles\\41.0.txt', 'txtfiles\\42.0.txt', 'txtfiles\\43.0.txt', 'txtfiles\\45.0.txt', 'txtfiles\\46.0.txt', 'txtfiles\\47.0.txt', 'txtfiles\\48.0.txt', 'txtfiles\\49.0.txt', 'txtfiles\\50.0.txt', 'txtfiles\\51.0.txt', 'txtfiles\\52.0.txt', 'txtfiles\\53.0.txt', 'txtfiles\\54.0.txt', 'txtfiles\\55.0.txt', 'txtfiles\\56.0.txt', 'txtfiles\\58.0.txt', 'txtfiles\\59.0.txt', 'txtfiles\\60.0.txt', 'txtfiles\\61.0.txt', 'txtfiles\\62.0.txt', 'txtfiles\\63.0.txt', 'txtfiles\\64.0.txt', 'txtfiles\\65.0.txt', 'txtfiles\\66.0.txt', 'txtfiles\\67.0.txt', 'txtfiles\\68.0.txt', 'txtfiles\\69.0.txt', 'txtfiles\\70.0.txt', 'txtfiles\\71.0.txt', 'txtfiles\\72.0.txt', 'txtfiles\\73.0.txt', 'txtfiles\\74.0.txt', 'txtfiles\\75.0.txt', 'txtfiles\\76.0.txt', 'txtfiles\\77.0.txt', 'txtfiles\\78.0.txt', 'txtfiles\\79.0.txt', 'txtfiles\\80.0.txt', 'txtfiles\\81.0.txt', 'txtfiles\\82.0.txt', 'txtfiles\\83.0.txt', 'txtfiles\\84.0.txt', 'txtfiles\\85.0.txt', 'txtfiles\\86.0.txt', 'txtfiles\\87.0.txt', 'txtfiles\\88.0.txt', 'txtfiles\\89.0.txt', 'txtfiles\\90.0.txt', 'txtfiles\\91.0.txt', 'txtfiles\\92.0.txt', 'txtfiles\\93.0.txt', 'txtfiles\\94.0.txt', 'txtfiles\\95.0.txt', 'txtfiles\\96.0.txt', 'txtfiles\\97.0.txt', 'txtfiles\\98.0.txt', 'txtfiles\\99.0.txt','txtfiles\\100.0.txt', 'txtfiles\\101.0.txt', 'txtfiles\\102.0.txt', 'txtfiles\\103.0.txt', 'txtfiles\\104.0.txt', 'txtfiles\\105.0.txt', 'txtfiles\\106.0.txt', 'txtfiles\\107.0.txt', 'txtfiles\\108.0.txt', 'txtfiles\\109.0.txt', 'txtfiles\\110.0.txt', 'txtfiles\\111.0.txt', 'txtfiles\\112.0.txt', 'txtfiles\\113.0.txt', 'txtfiles\\114.0.txt', 'txtfiles\\115.0.txt', 'txtfiles\\116.0.txt', 'txtfiles\\117.0.txt', 'txtfiles\\118.0.txt', 'txtfiles\\119.0.txt', 'txtfiles\\120.0.txt', 'txtfiles\\121.0.txt', 'txtfiles\\122.0.txt', 'txtfiles\\123.0.txt', 'txtfiles\\124.0.txt', 'txtfiles\\125.0.txt', 'txtfiles\\126.0.txt', 'txtfiles\\127.0.txt', 'txtfiles\\128.0.txt', 'txtfiles\\129.0.txt', 'txtfiles\\130.0.txt', 'txtfiles\\131.0.txt', 'txtfiles\\132.0.txt', 'txtfiles\\133.0.txt', 'txtfiles\\134.0.txt', 'txtfiles\\135.0.txt', 'txtfiles\\136.0.txt', 'txtfiles\\137.0.txt', 'txtfiles\\138.0.txt', 'txtfiles\\139.0.txt', 'txtfiles\\140.0.txt', 'txtfiles\\141.0.txt', 'txtfiles\\142.0.txt', 'txtfiles\\143.0.txt', 'txtfiles\\145.0.txt', 'txtfiles\\146.0.txt', 'txtfiles\\147.0.txt', 'txtfiles\\148.0.txt', 'txtfiles\\149.0.txt', 'txtfiles\\150.0.txt']
uids=[]
positive_scores=[]
negative_scores=[]
polarity_scores=[]
subjectivity_scores=[]
average_sentence_lengths=[]
percentage_complex_wordss=[]
fog_indexs=[]
avg_no_words_sentences=[]
num_complex_wordss=[]
word_count_nltks=[]
syllable_counts=[]
personal_pronounss=[]
average_word_lengths=[]


for iters in filess:
    
    text_uid= iters.split('\\')[-1].split(".")[0]
    print(text_uid)
    print(iters)
    stopword_files = ['StopWords\StopWords_Auditor.txt','StopWords\StopWords_Currencies.txt','StopWords\StopWords_DatesandNumbers.txt','StopWords\StopWords_Generic.txt','StopWords\StopWords_GenericLong.txt','StopWords\StopWords_Geographic.txt','StopWords\StopWords_Names.txt']

    stopwords = set()

    for file in stopword_files:
        with open(file, 'r') as f:
            words = f.read().splitlines()
            stopwords.update(words)

    with open(iters, 'r', encoding='utf-8', errors='ignore') as file:
        text = file.read()

    words = word_tokenize(text)

    filtered_words = [word for word in words if word.casefold() not in stopwords]
    output_file='output/filtered{}.txt'.format(text_uid)
    with open(output_file, 'w') as file:
        file.write(' '.join(filtered_words))
    positive_words = {}
    negative_words = {}
    d = cmudict.dict()
    def count_syllables(word):
        vowels = "aeiouy"
        count = 0
        prev_char = None
        for char in word:
            char = char.lower()
            if char in vowels and (prev_char is None or prev_char not in vowels):
                count += 1
            prev_char = char
        if word.endswith("e"):
            count -= 1
        if count == 0:
            count = 1
        return count

    with open('MasterDictionary\positive-words.txt', 'r') as f:
        for line in f:
            positive_words[line.strip()] = 1

    with open(r'MasterDictionary\negative-words.txt', 'r') as f:
        for line in f:
            negative_words[line.strip()] = 1

    with open(output_file, 'r', encoding='utf-8', errors='ignore') as file:
        text = file.read()
    sentences = nltk.sent_tokenize(text)
    no_of_sentences=len(sentences)

    def word_count_nltk(text):
        c_stopwords=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
        filtered_words = [word.lower() for word in text if (word.lower() not in c_stopwords) and (word.lower() not in string.punctuation)]
        num_words = len(filtered_words)
        return num_words
        

    def count_personal_pronouns(word):
        personal_pronouns = ['i', 'me', 'my', 'mine', 'myself', 'we', 'us', 'our', 'ours', 'ourselves', 'you', 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves']
        count = 0
        if word.lower() in personal_pronouns:
            count += 1
        return count


    words = text.split()
    total_word_count = len(words)
    complex_words = [word for word in words if count_syllables(word) > 2]
    num_complex_words = len(complex_words)

    word_ncount=word_count_nltk(text)
    positive_score = sum(1 for word in words if word in positive_words)
    negative_score = sum(1 for word in words if word in negative_words)
    polarity_score = (positive_score - negative_score )/((positive_score + negative_score) + 0.000001)
    subjectivity_score = (polarity_score + negative_score)/ ((total_word_count) + 0.000001)
    average_sentence_length = total_word_count / no_of_sentences
    percentage_complex_words = num_complex_words/total_word_count
    fog_index = 0.4 *(average_sentence_length + percentage_complex_words)
    avg_no_words_sentence = total_word_count/no_of_sentences
    syllable_count = sum(count_syllables(word) for word in words)/total_word_count
    personal_pronouns=sum(count_personal_pronouns(word) for word in words)
    average_word_length=sum(len(word) for word in words)/total_word_count


    print("Positive Score:", positive_score)
    print("Negative Score:", negative_score)
    print("Polarity Score:", polarity_score)
    print("Subjectivity Score:",subjectivity_score)
    print("Average Sentence Length", average_sentence_length)
    print("Percentage of complex words:", percentage_complex_words)
    print("Fog Index:", fog_index)
    print("Average Number of Words Per Sentence:", avg_no_words_sentence)
    print("Complex Word Count:", num_complex_words)
    print("Word Count:", word_ncount)
    print("Syllable Count Per Word:",syllable_count)
    print("Personal Pronouns:",personal_pronouns)
    print("Average Word Length:", average_word_length)
    
    uids.append(text_uid)
    positive_scores.append(positive_score)
    negative_scores.append(negative_score)
    polarity_scores.append(polarity_score)
    subjectivity_scores.append(subjectivity_score)
    average_sentence_lengths.append(average_sentence_length)
    percentage_complex_wordss.append(percentage_complex_words)
    fog_indexs.append(fog_index)
    avg_no_words_sentences.append(avg_no_words_sentence)
    num_complex_wordss.append(num_complex_words)
    word_count_nltks.append(word_ncount)
    syllable_counts.append(syllable_count)
    personal_pronounss.append(personal_pronouns)
    average_word_lengths.append(average_word_length)

dfs={
    'uid':uids,
    'POSITIVE SCORE':positive_scores,
    'NEGATIVE SCORE':negative_scores,
    'POLARITY SCORE':polarity_scores,
    'SUBJECTIVITY SCORE':subjectivity_scores,
    'AVERAGE SENTENCE LENGTH':average_sentence_lengths,
    'PERCENTAGE OF COMPLEX WORDS':percentage_complex_wordss,
    'FOG INDEX':fog_indexs,
    'AVG NUMBER OF WORDS PER SENTENCE':avg_no_words_sentences,
    'COMPLEX WORD COUNT':num_complex_wordss,
    'WORD COUNT':word_count_nltks,
    'SYLLABLE PER WORD':syllable_counts,
    'PERSONAL PRONOUNS':personal_pronounss,
    'AVG WORD LENGTH':average_word_lengths
}
df=pd.DataFrame(dfs)
df.to_excel("Trailf.xlsx")
# Out:
# 37
# txtfiles\37.0.txt
# Positive Score: 60
# Negative Score: 33
# Polarity Score: 0.2903225775234132
# Subjectivity Score: 0.027422011985256504
# Average Sentence Length 15.766233766233766
# Percentage of complex words: 0.3624382207578254
# Fog Index: 6.451468794796637
# Average Number of Words Per Sentence: 15.766233766233766
# Complex Word Count: 440
# Word Count: 5179
# Syllable Count Per Word: 2.224052718286656
# Personal Pronouns: 0
# Average Word Length: 6.457166392092257
# 38
# txtfiles\38.0.txt
# Positive Score: 56
# Negative Score: 38
# Polarity Score: 0.19148935966500683
# Subjectivity Score: 0.04767976193755961
# Average Sentence Length 10.0125
# Percentage of complex words: 0.2696629213483146
# Fog Index: 4.112865168539326
# Average Number of Words Per Sentence: 10.0125
# Complex Word Count: 216
# Word Count: 3092
# Syllable Count Per Word: 1.9275905118601748
# Personal Pronouns: 0
# Average Word Length: 5.474406991260924
# 39
# txtfiles\39.0.txt
# Positive Score: 65
# ...
